# %%
# Import necessary modules
import data_preprocessor as dp
import pandas as pd


# 1. Load and examine the dataset
# messy_data = pd.read_csv('../Data/messy_data.csv')
# clean_data = messy_data.copy()
# messy_data.head()
# messy_data.info()
# messy_data.describe()
heart_data = pd.read_csv('../Data/heart_disease_uci(1).csv')
heart_clean = heart_data.copy()
#heart_data.head()
#heart_data.info()
#heart_data.describe()

# 2. Preprocess the data (messy data)
#clean_data = dp.impute_missing_values(clean_data, strategy='mean')
#clean_data = dp.remove_duplicates(clean_data)
#clean_data = dp.normalize_data(clean_data)
#clean_data = dp.remove_redundant_features(clean_data)
#clean_data = dp.convert_categorical(clean_data)

# 2. Preprocess the data (heart data)
heart_clean = dp.impute_missing_values(heart_clean, strategy='mean')
heart_clean = dp.remove_duplicates(heart_clean)
heart_clean = dp.remove_redundant_features(heart_clean)
heart_clean = dp.convert_categorical(heart_clean)

# 3. Save the cleaned dataset
# clean_data.to_csv('../Data/clean_data.csv', index=False)
# clean_data = pd.read_csv('../Data/clean_data.csv')


# 4. Train and evaluate the model (messy data)
# dp.simple_model(input_data=clean_data, print_report=True, threshold=0.5)

# 4. Train and evaluate the model (heart data)
#dp.linear_regression(input_data=heart_clean, target_col="chol", test_size=0.2, scale_data=False)
dp.logistic_regression(input_data=heart_clean, target_col="num", test_size=0.2, scale_data=False)
dp.knn_classifier(input_data=heart_clean, target_col="num", scale_data=True, print_report=True)

# Comparision to the previous data
# clean_data.head()
# clean_data.info()
# clean_data.describe()
# Out:
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64
# /Users/why/Desktop/pythonProject/Project 2/BINF5507Project/Data-Wrangling/Assignment1/Scripts/data_preprocessor.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)
# ...
